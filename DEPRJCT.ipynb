# %%
! pip install tweepy
! pip install kafka-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
import socket
import json
from kafka import KafkaConsumer, KafkaProducer
import time

# %%
consumer_key='******************'
consumer_secret='***************************'
access_token ='*******************************'
access_secret='*************************************'
# Creating the authentication object
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# Setting your access token and secret
auth.set_access_token(access_token, access_secret)
# Creating the API object by passing in auth information
api = tweepy.API(auth) 

Hastag="السعودية"

# %%
from datetime import datetime, timedelta

def normalize_timestamp(time):
    mytime = datetime.strptime(time, "%Y-%m-%d %H:%M:%S")
    mytime += timedelta(hours=1)   # the tweets are timestamped in GMT timezone, while I am in +1 timezone
    return (mytime.strftime("%Y-%m-%d %H:%M:%S"))

# %%
def get_twitter_data():
    res = api.search(Hastag)
    producer.send(topic_name)

# %%
# !wget https://dlcdn.apache.org/kafka/3.3.1/kafka_2.13-3.3.1.tgz
# !tar -xzf kafka_2.13-3.3.1.tgz
# Out:
# --2022-10-08 00:23:12--  https://dlcdn.apache.org/kafka/3.3.1/kafka_2.13-3.3.1.tgz
# Resolving dlcdn.apache.org (dlcdn.apache.org)... 151.101.2.132, 2a04:4e42::644
# Connecting to dlcdn.apache.org (dlcdn.apache.org)|151.101.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 105053134 (100M) [application/x-gzip]
# Saving to: ‘kafka_2.13-3.3.1.tgz’
#
# kafka_2.13-3.3.1.tg 100%[===================>] 100.19M   312MB/s    in 0.3s
#
# 2022-10-08 00:23:12 (312 MB/s) - ‘kafka_2.13-3.3.1.tgz’ saved [105053134/105053134]

# %%
# %cd kafka_2.13-3.3.1
# Out:
# /content/kafka_2.13-3.3.1

# %%
# !bin/zookeeper-server-start.sh -daemon config/zookeeper.properties

# %%
# !bin/kafka-server-start.sh -daemon config/server.properties

# %%
# !bin/kafka-topics.sh --create \
    --bootstrap-server localhost:9092 \
    --replication-factor 1 \
    --partitions 1 \
    --topic AIHSTREAM
# Out:
# Created topic AIHSTREAM.

# %%
# !bin/kafka-topics.sh --list --bootstrap-server localhost:9092
# Out:
# AIHSTREAM
# Tuwaiq

# %%
# !bin/kafka-console-producer.sh --bootstrap-server localhost:9092 --topic AIHSTREAM

# %%
# !bin/kafka-console-consumer.sh --topic AIHSTREAM --from-beginning --bootstrap-server localhost:9092
# Out:
# 411275868;2022-10-08 01:27:02;690;;0;0;
# 1558693153644785664;2022-10-08 01:27:02;121;;0;34636;
# 1177373038809010178;2022-10-08 01:27:02;66;;0;24587;
# 800397522;2022-10-08 01:27:02;197;;0;0;
# 1122540879162617856;2022-10-08 01:27:02;13631;Florida, USA;0;3;
# 896989580;2022-10-08 01:27:01;1408;犬界;0;254;
# 1387288548865237001;2022-10-08 01:27:01;758;初心者歓迎🔰お得情報／ヤフショ＆各通販活用情報オプチャ;0;0;
# 1383150017918164997;2022-10-08 01:27:01;25;Swanzey, NH;0;0;
# 3701281;2022-10-08 01:27:01;6007;;0;0;
# 1271266362426605570;2022-10-08 01:27:00;195;;0;0;
# 26832476;2022-10-08 01:27:00;545;;0;599;
# 40419412;2022-10-08 01:27:39;1074;High Flying Disk;0;36;
# 1359583098581696518;2022-10-08 01:27:38;90;;0;17290;
# 131638117;2022-10-08 01:27:38;38;México, Distrito Federal;0;0;
# 1497021103373713408;2022-10-08 01:27:38;463;;0;2325;
# 1528440783145418752;2022-10-08 01:27:37;81;;0;0;
# 1195847811855605760;2022-10-08 01:27:37;2481;日本 東京;0;0;
# 1378085948819378176;2022-10-08 01:33:53;43;;0;0;
# ...

# %%
get_twitter_data()

# %%
! bin/kafka-console-consumer.sh --zookeeper localhost:9092 --topic AIHSTREAM >| file.csv
# Out:
# zookeeper is not a recognized option
# Option                                   Description
# ------                                   -----------
# --bootstrap-server <String: server to    REQUIRED: The server(s) to connect to.
#   connect to>
# --consumer-property <String:             A mechanism to pass user-defined
#   consumer_prop>                           properties in the form key=value to
#                                            the consumer.
# --consumer.config <String: config file>  Consumer config properties file. Note
#                                            that [consumer-property] takes
#                                            precedence over this config.
# --enable-systest-events                  Log lifecycle events of the consumer
#                                            in addition to logging consumed
#                                            messages. (This is specific for
#                                            system tests.)
# ...
